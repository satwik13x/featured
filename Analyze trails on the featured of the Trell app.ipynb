# %%
# Analyze trails on the “featured” of the Trell app. 
#What are the metrics that you’ll be tracking for better user engagement?

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('feature.csv')
print(df.head())
# Out:
#    Number_of_downloads          activity country  gender
# 0                65820        Food&Drink  indian  female
# 1                45809            Travel  indian  female
# 2                45802      Arts&Culture  indian  female
# 3                45805          Adenture  indian  female
# 4                65803  Local_Attrations  indian  female

# %%
f, ax = plt.subplots(figsize=(15, 10))

fmt = '{x:,.0f}L'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)

sns.barplot(data=df, x="country", y = "Number_of_downloads", hue="gender")
plt.show()
